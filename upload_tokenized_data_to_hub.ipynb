# %% [markdown]
# # Imports

# %%
import torch
from datasets import load_dataset, load_from_disk

# %% [markdown]
# # Data

# %%
data = load_from_disk(f'{path}/tokenized_data_384.hf') # ~ 2 min
data = data.with_format('torch') # format using tensors rather than native Python;
# otherwise batches give lists not tensors
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'input_ids', 'attention_mask'],
#         num_rows: 2119719
#     })
#     validation: Dataset({
#         features: ['text', 'input_ids', 'attention_mask'],
#         num_rows: 21990
#     })
# })

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
data.push_to_hub(repo_id='terru3/tokenized_tinystories384', private=False)
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/22 [00:00<?, ?ba/s]
